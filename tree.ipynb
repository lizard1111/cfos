# %%
import json
import plotly.graph_objects as go

# Load the JSON file
with open('structures.json', 'r') as f:
    data = json.load(f)

# Prepare data for the tree
labels = [item['acronym'] for item in data]
parents = ['' if len(item['structure_id_path']) == 1 else next((i['acronym'] for i in data if i['id'] == item['structure_id_path'][-2])) for item in data]

colors = ['rgb{}'.format(tuple(item['rgb_triplet'])) for item in data]

# Create a Plotly figure
fig = go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    marker=dict(colors=colors),
))

fig.update_layout(margin=dict(t=0, l=0, r=0, b=0))

fig.show()

# %%
print(parents)
# Out:
# ['', 'root', 'grey', 'CH', 'CTX', 'CTXpl', 'Isocortex', 'FRP', 'FRP', 'FRP', 'FRP', 'FRP', 'Isocortex', 'MO', 'MO', 'MO', 'MO', 'MO', 'MO', 'MOp', 'MOp', 'MOp', 'MOp', 'MOp', 'MO', 'MOs', 'MOs', 'MOs', 'MOs', 'MOs', 'Isocortex', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SS', 'SSp', 'SSp', 'SSp', 'SSp', 'SSp', 'SSp', 'SSp', 'SSp-n', 'SSp-n', 'SSp-n', 'SSp-n', 'SSp-n', 'SSp-n', 'SSp', 'SSp-bfd', 'SSp-bfd', 'SSp-bfd', 'SSp-bfd', 'SSp-bfd', 'SSp-bfd', 'SSp-bfd', 'VISrll', 'VISrll', 'VISrll', 'VISrll', 'VISrll', 'VISrll', 'SSp', 'SSp-ll', 'SSp-ll', 'SSp-ll', 'SSp-ll', 'SSp-ll', 'SSp-ll', 'SSp', 'SSp-m', 'SSp-m', 'SSp-m', 'SSp-m', 'SSp-m', 'SSp-m', 'SSp', 'SSp-ul', 'SSp-ul', 'SSp-ul', 'SSp-ul', 'SSp-ul', 'SSp-ul', 'SSp', 'SSp-tr', 'SSp-tr', 'SSp-tr', 'SSp-tr', 'SSp-tr', 'SSp-tr', 'SSp', 'SSp-un', 'SSp-un', 'SSp-un', 'SSp-un', 'SSp-un', 'SSp-un', 'SS', 'SSs', 'SSs', 'SSs', 'SSs', 'SSs', 'SSs', 'Isocortex', 'GU', 'GU', 'GU', 'GU', 'GU', 'GU', 'Isocortex', 'VISC', 'VISC', 'VISC', 'VISC', 'VISC', '
# ...

# %%
import pandas as pd

# Read the original CSV file
df = pd.read_csv('FemaleRR_Fed_Fos_output.csv')

# Split the 'name' column to extract the side information (left/right)
df[['side', 'name']] = df['name'].str.split(' ', n=1, expand=True)

# Strip any whitespace from the 'side' and 'name' columns
df['side'] = df['side'].str.strip()
df['name'] = df['name'].str.strip()

# Remove '-L' or '-R' suffix from the 'name' column
df['acronym'] = df['acronym'].str.replace('-L$', '').str.replace('-R$', '')

# Split the DataFrame into two separate DataFrames for left and right sides
left_df = df[df['side'] == 'left']
right_df = df[df['side'] == 'right']

# Drop the 'side' column from both DataFrames
left_df.drop('side', axis=1, inplace=True)
right_df.drop('side', axis=1, inplace=True)

# Define the new filenames for the left and right CSV files
left_filename = 'your_original_csv_filename_left.csv'
right_filename = 'your_original_csv_filename_right.csv'

# Save the left and right DataFrames to new CSV files
left_df.to_csv(left_filename, index=False)
right_df.to_csv(right_filename, index=False)

print(f"Left CSV saved as: {left_filename}")
print(f"Right CSV saved as: {right_filename}")
# Out:
# Left CSV saved as: your_original_csv_filename_left.csv
# Right CSV saved as: your_original_csv_filename_right.csv

# %%
import pandas as pd

# Read the original CSV file
df = pd.read_csv('MaleL_FastRefeed_Fos_output.csv')

# Split the 'name' column to extract the side information (left/right)
df[['side', 'name']] = df['name'].str.split(' ', n=1, expand=True)

# Strip any whitespace from the 'side' and 'name' columns
df['side'] = df['side'].str.strip()
df['name'] = df['name'].str.strip()

# Remove '-L' or '-R' suffix from the 'acronym' column
df['acronym'] = df['acronym'].str.replace('-L', '').str.replace('-R', '')

# Split the DataFrame into two separate DataFrames for left and right sides
left_df = df[df['side'] == 'left']
right_df = df[df['side'] == 'right']

# Drop the 'side' column from both DataFrames
left_df.drop('side', axis=1, inplace=True)
right_df.drop('side', axis=1, inplace=True)

# Define the new filenames for the left and right CSV files
left_filename = 'MaleL_FastRefeed_Fos_Left.csv'
right_filename = 'MaleL_FastRefeed_Fos_Right.csv'

# Save the left and right DataFrames to new CSV files
left_df.to_csv(left_filename, index=False)
right_df.to_csv(right_filename, index=False)

print(f"Left CSV saved as: {left_filename}")
print(f"Right CSV saved as: {right_filename}")
# Out:
# Left CSV saved as: MaleL_FastRefeed_Fos_Left.csv
# Right CSV saved as: MaleL_FastRefeed_Fos_Right.csv

# %%
import pandas as pd

# Read the original CSV file
df = pd.read_csv('FemaleRR_Fed_Fos_output.csv')

# Split the 'name' column to extract the side information (left/right)
df[['side', 'name']] = df['name'].str.split(' ', n=1, expand=True)

# Strip any whitespace from the 'side' and 'name' columns
df['side'] = df['side'].str.strip()
df['name'] = df['name'].str.strip()

# Convert 'acronym' column to string type
df['acronym'] = df['acronym'].astype(str)

# Remove '-L' or '-R' suffix from the 'acronym' column
df['acronym'] = df['acronym'].str.replace('-L', '').str.replace('-R', '')

# Split the DataFrame into two separate DataFrames for left and right sides
left_df = df[df['side'] == 'left']
right_df = df[df['side'] == 'right']

# Drop the 'side' column from both DataFrames
left_df.drop('side', axis=1, inplace=True)
right_df.drop('side', axis=1, inplace=True)

# Define the new filenames for the left and right CSV files
left_filename = 'your_original_csv_filename_left.csv'
right_filename = 'your_original_csv_filename_right.csv'

# Save the left and right DataFrames to new CSV files
left_df.to_csv(left_filename, index=False)
right_df.to_csv(right_filename, index=False)

print(f"Left CSV saved as: {left_filename}")
print(f"Right CSV saved as: {right_filename}")
# Out:
# Left CSV saved as: your_original_csv_filename_left.csv
# Right CSV saved as: your_original_csv_filename_right.csv

# %%
import json

combined_data = []

# Load the JSON file
with open('structures.json', 'r') as f:
    json_data = json.load(f)

df = pd.read_csv('your_original_csv_filename_right.csv')

for json_structure in json_data:
    acronym = json_structure['acronym']
    csv_row = df[df['acronym'] == acronym]
    
    if not csv_row.empty:
        count = csv_row['count'].values[0]
        
        combined_structure = {
            'acronym': acronym,
            'rgb_triplet': json_structure['rgb_triplet'],
            'graph_id': json_structure['graph_id'],
            'graph_order': json_structure['graph_order'],
            'id': json_structure['id'],
            'name': json_structure['name'],
            'structure_id_path': json_structure['structure_id_path'],
            'structure_set_ids': json_structure['structure_set_ids'],
            'count': count
        }
        
        combined_data.append(combined_structure)

# %%
import json

# Save the combined_data as JSON
with open('combined_data.json', 'w') as f:
    json.dump(combined_data, f)

# %%
import json
import plotly.graph_objects as go
import pandas as pd

# Load the JSON file
with open('structures.json', 'r') as f:
    data = json.load(f)

# Read the CSV file
df = pd.read_csv('Fed.csv')

# Prepare data for the tree
labels = [item['acronym'] for item in data]
parents = ['' if len(item['structure_id_path']) == 1 else next((i['acronym'] for i in data if i['id'] == item['structure_id_path'][-2])) for item in data]

# Match acronyms with count values from the CSV
counts = [df.loc[df['acronym'] == acronym, 'density (cells/mm^3)'].iloc[0] if acronym in df['acronym'].values else None for acronym in labels]

colors = ['rgb{}'.format(tuple(item['rgb_triplet'])) for item in data]

# Create a Plotly figure
fig = go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    values=counts,  # Assign count values to the sunburst
    marker=dict(colors=colors),
    hovertemplate='<b>%{label}</b><br>Count: %{value}<extra></extra>',  # Customize hover text
))

fig.update_layout(margin=dict(t=0, l=0, r=0, b=0))

fig.show()

# %%
import json
import plotly.graph_objects as go
import pandas as pd

# Load the JSON file
with open('structures.json', 'r') as f:
    data = json.load(f)

# Read the CSV file
df = pd.read_csv('FastRefeed.csv')

# Prepare data for the tree
labels = [item['acronym'] for item in data]
parents = ['' if len(item['structure_id_path']) == 1 else next((i['acronym'] for i in data if i['id'] == item['structure_id_path'][-2])) for item in data]

# Match acronyms with count values from the CSV
counts = [df.loc[df['acronym'] == acronym, 'density (cells/mm^3)'].iloc[0] if acronym in df['acronym'].values else None for acronym in labels]

colors = ['rgb{}'.format(tuple(item['rgb_triplet'])) for item in data]

# Create a Plotly figure
fig = go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    values=counts,  # Assign count values to the sunburst
    marker=dict(colors=colors),
    hovertemplate='<b>%{label}</b><br>density (cells/mm^3): %{value}<extra></extra>',  # Customize hover text
))

fig.update_layout(margin=dict(t=0, l=0, r=0, b=0))

fig.show()

# %%
import json
import plotly.graph_objects as go
import pandas as pd

# Load the JSON file
with open('structures.json', 'r') as f:
    data = json.load(f)

# Read the CSV file
df = pd.read_csv('FastRefeed.csv')

# Prepare data for the tree
labels = [item['acronym'] for item in data]
parents = ['' if len(item['structure_id_path']) == 1 else next((i['acronym'] for i in data if i['id'] == item['structure_id_path'][-2])) for item in data]

# Match acronyms with count values from the CSV
counts = [df.loc[df['acronym'] == acronym, 'density (cells/mm^3)'].iloc[0] if acronym in df['acronym'].values else None for acronym in labels]

colors = ['rgb{}'.format(tuple(item['rgb_triplet'])) for item in data]

# Create a Plotly figure
fig = go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    values=counts,  # Assign count values to the sunburst
    marker=dict(colors=colors),
    hovertemplate='<b>%{label}</b><br>density (cells/mm^3): %{value}<extra></extra>',  # Customize hover text
))

# Update the layout with black background
fig.update_layout(
    plot_bgcolor='black',
    paper_bgcolor='black',
    margin=dict(t=10, l=0, r=0, b=0)
)

fig.show()

# %%
import pandas as pd

# Read the four CSV files
df_fed_1 = pd.read_csv('FemaleRR_Fed_Fos_Right.csv')
df_fed_2 = pd.read_csv('MaleR_Fed_Fos_Right.csv')
df_fastrefeed_1 = pd.read_csv('MaleL_FastRefeed_Fos_Right.csv')
df_fastrefeed_2 = pd.read_csv('Male2_FastRefeed_Fos_Right.csv')

# Calculate the average of 'count' and 'density (cells/mm^3)' for Fed
avg_count_fed = (df_fed_1['count'] + df_fed_2['count']) / 2
avg_density_fed = (df_fed_1['density (cells/mm^3)'] + df_fed_2['density (cells/mm^3)']) / 2

# Create a new DataFrame for Fed
df_fed = pd.DataFrame({'count': avg_count_fed, 'density (cells/mm^3)': avg_density_fed})

# Calculate the average of 'count' and 'density (cells/mm^3)' for FastRefeed
avg_count_fastrefeed = (df_fastrefeed_1['count'] + df_fastrefeed_2['count']) / 2
avg_density_fastrefeed = (df_fastrefeed_1['density (cells/mm^3)'] + df_fastrefeed_2['density (cells/mm^3)']) / 2

# Create a new DataFrame for FastRefeed
df_fastrefeed = pd.DataFrame({'count': avg_count_fastrefeed, 'density (cells/mm^3)': avg_density_fastrefeed})

# Save the new DataFrames as CSV files
df_fed.to_csv('Fed.csv', index=False)
df_fastrefeed.to_csv('FastRefeed.csv', index=False)

# %%
import pandas as pd

# Read the four CSV files
df_fed_1 = pd.read_csv('FemaleRR_Fed_Fos_Right.csv')
df_fed_2 = pd.read_csv('MaleR_Fed_Fos_Right.csv')
df_fastrefeed_1 = pd.read_csv('MaleL_FastRefeed_Fos_Right.csv')
df_fastrefeed_2 = pd.read_csv('Male2_FastRefeed_Fos_Right.csv')

# Concatenate the four DataFrames into two separate DataFrames for Fed and FastRefeed
df_fed = pd.concat([df_fed_1, df_fed_2])
df_fastrefeed = pd.concat([df_fastrefeed_1, df_fastrefeed_2])

# Group by 'acronym' and calculate the mean for numeric columns
df_fed = df_fed.groupby('id').mean(numeric_only=True).reset_index()
df_fastrefeed = df_fastrefeed.groupby('id').mean(numeric_only=True).reset_index()

# Save the new DataFrames as CSV files
df_fed.to_csv('Fed_id_right.csv', index=False)
df_fastrefeed.to_csv('FastRefeed_id_right.csv', index=False)

# %%
import json
import plotly.graph_objects as go
import pandas as pd

# Load the JSON file
with open('structures.json', 'r') as f:
    data = json.load(f)

# Read the CSV files
df_Fed = pd.read_csv('Fed.csv')
df_FastRefeed = pd.read_csv('FastRefeed.csv')

# Prepare data for the tree
labels = [item['acronym'] for item in data]
parents = ['' if len(item['structure_id_path']) == 1 else next((i['acronym'] for i in data if i['id'] == item['structure_id_path'][-2])) for item in data]

# Match acronyms with count values from the CSVs
density_fed = [df_Fed.loc[df_left['acronym'] == acronym, 'density (cells/mm^3)'].iloc[0] if acronym in df_Fed['acronym'].values else None for acronym in labels]

density_FastRefeed = [df_FastRefeed.loc[df_FastRefeed['acronym'] == acronym, 'density (cells/mm^3)'].iloc[0] if acronym in df_FastRefeed['acronym'].values else None for acronym in labels]

count_fed = [df_Fed.loc[df_Fed['acronym'] == acronym, 'count'].iloc[0] if acronym in df_Fed['acronym'].values else None for acronym in labels]

count_FastRefeed = [df_FastRefeed.loc[df_FastRefeed['acronym'] == acronym, 'count'].iloc[0] if acronym in df_FastRefeed['acronym'].values else None for acronym in labels]

colors = ['rgb{}'.format(tuple(item['rgb_triplet'])) for item in data]

# Create the figure with subplots
fig = go.Figure()

# Add the left sunburst
fig.add_trace(go.Sunburst(
    labels=labels,
    parents=parents,
    values=density_fed,  # Assign count values to the sunburst
    marker=dict(colors=colors),
    hovertemplate='<b>%{label}</b><br>density: %{value}<extra></extra>',  # Customize hover text
    domain=dict(column=0),
))

# Add the right sunburst
fig.add_trace(go.Sunburst(
    labels=labels,
    parents=parents,
    values=density_FastRefeed,  # Assign count values to the sunburst
    marker=dict(colors=colors),
    hovertemplate='<b>%{label}</b><br>density: %{value}<extra></extra>',  # Customize hover text
    domain=dict(column=1),
))

fig.add_trace(go.Sunburst(
    labels=labels,
    parents=parents,
    values=count_fed,  # Assign count values to the sunburst
    marker=dict(colors=colors),
    hovertemplate='<b>%{label}</b><br>count: %{value}<extra></extra>',  # Customize hover text
    domain=dict(column=1, row=1),
))

fig.update_layout(
    grid=dict(columns=2, rows=2),
    margin=dict(t=0, l=0, r=0, b=0)
)

fig.show()

# %%
import pandas as pd

# Read the four CSV files
df_fed_1 = pd.read_csv('FemaleRR_Fed_Fos_Right.csv')
df_fed_2 = pd.read_csv('MaleR_Fed_Fos_Right.csv')
df_fastrefeed_1 = pd.read_csv('MaleL_FastRefeed_Fos_Right.csv')
df_fastrefeed_2 = pd.read_csv('Male2_FastRefeed_Fos_Right.csv')

# Concatenate the four DataFrames into two separate DataFrames for Fed and FastRefeed
df_fed = pd.concat([df_fed_1, df_fed_2])
df_fastrefeed = pd.concat([df_fastrefeed_1, df_fastrefeed_2])

# Group by 'acronym' and 'name' and calculate the mean for 'count' and 'density' columns
df_fed = df_fed.groupby(['acronym', 'name'])[['count', 'density (cells/mm^3)']].mean().reset_index()
df_fastrefeed = df_fastrefeed.groupby(['acronym', 'name'])[['count', 'density (cells/mm^3)']].mean().reset_index()

# Save the new DataFrames as CSV files
df_fed.to_csv('Fed.csv', index=False)
df_fastrefeed.to_csv('FastRefeed.csv', index=False)

# %%
import json
import plotly.graph_objects as go
import pandas as pd

# Load the JSON file
with open('structures.json', 'r') as f:
    data = json.load(f)

# Read the CSV files
df_Fed = pd.read_csv('Fed.csv')
df_FastRefeed = pd.read_csv('FastRefeed.csv')

# Prepare data for the tree
labels = [item['acronym'] for item in data]
parents = ['' if len(item['structure_id_path']) == 1 else next((i['acronym'] for i in data if i['id'] == item['structure_id_path'][-2])) for item in data]

# Match acronyms with count values from the CSVs
counts_Fed = [df_Fed.loc[df_Fed['acronym'] == acronym, 'density (cells/mm^3)'].iloc[0] if acronym in df_Fed['acronym'].values else None for acronym in labels]
counts_FastRefeed = [df_FastRefeed.loc[df_FastRefeed['acronym'] == acronym, 'density (cells/mm^3)'].iloc[0] if acronym in df_FastRefeed['acronym'].values else None for acronym in labels]

colors = ['rgb{}'.format(tuple(item['rgb_triplet'])) for item in data]

# Create the figure with subplots
fig = go.Figure()

# Add the left sunburst with title
fig.add_trace(go.Sunburst(
    labels=labels,
    parents=parents,
    values=counts_Fed,  # Assign count values to the sunburst
    marker=dict(colors=colors),
    hovertemplate='%{label}<br>Count: %{value}',  # Customize hover text
    domain=dict(column=0),
    insidetextorientation='tangential'
))

fig.update_layout(
    annotations=[
        go.layout.Annotation(
            text='Fed',
            x=0.5,
            y=1.12,
            showarrow=False,
            font=dict(size=16),
            xref='paper',
            yref='paper'
        )
    ],
    grid=dict(columns=2, rows=1),
    margin=dict(t=0, l=0, r=0, b=0)
)

# Add the right sunburst with title
fig.add_trace(go.Sunburst(
    labels=labels,
    parents=parents,
    values=counts_FastRefeed,  # Assign count values to the sunburst
    marker=dict(colors=colors),
    hovertemplate='%{label}<br>Count: %{value}',  # Customize hover text
    domain=dict(column=1),
))

fig.update_layout(
    annotations=[
        go.layout.Annotation(
            text='FastRefeed',
            x=0.5,
            y=1.12,
            showarrow=False,
            font=dict(size=16),
            xref='paper',
            yref='paper'
        )
    ],
    grid=dict(columns=2, rows=1),
    margin=dict(t=0, l=0, r=0, b=0)
)

fig.show()

# %%
import json
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# Load the JSON file
with open('structures.json', 'r') as f:
    data = json.load(f)

# Read the CSV files
df_Fed = pd.read_csv('Fed.csv')
df_FastRefeed = pd.read_csv('FastRefeed.csv')

# Prepare data for the tree
labels = [item['acronym'] for item in data]
parents = ['' if len(item['structure_id_path']) == 1 else next((i['acronym'] for i in data if i['id'] == item['structure_id_path'][-2])) for item in data]

# Match acronyms with count values from the CSVs
counts_Fed = [df_Fed.loc[df_Fed['acronym'] == acronym, 'density (cells/mm^3)'].iloc[0] if acronym in df_Fed['acronym'].values else None for acronym in labels]
counts_FastRefeed = [df_FastRefeed.loc[df_FastRefeed['acronym'] == acronym, 'density (cells/mm^3)'].iloc[0] if acronym in df_FastRefeed['acronym'].values else None for acronym in labels]

# Calculate percent change in density of cells
percent_change = [(count_fast - count_fed) / count_fed * 100 if count_fed is not None else None for count_fed, count_fast in zip(counts_Fed, counts_FastRefeed)]

# Define the color scale for percent change
color_scale = [[-100, 'blue'], [0, 'white'], [1000, 'red']]

# Map percent change to color values
colors = [np.interp(pc, [0, 300], [0, 1]) if pc is not None else None for pc in percent_change]

# Create the figure with subplots
fig = go.Figure()

# Add the left sunburst with title
fig.add_trace(go.Sunburst(
    labels=labels,
    parents=parents,
    values=counts_Fed,
    marker=dict(colors=colors, colorbar=dict(title='Percent Change')),
    hovertemplate='%{label}<br>Count: %{value}<br>Percent Change: %{customdata:.2f}%',
    customdata=percent_change,
    domain=dict(column=0),
    insidetextorientation='tangential'
))

fig.update_layout(
    annotations=[
        go.layout.Annotation(
            text='Fed',
            x=0.5,
            y=1.12,
            showarrow=False,
            font=dict(size=16),
            xref='paper',
            yref='paper'
        )
    ],
    grid=dict(columns=2, rows=1),
    margin=dict(t=0, l=0, r=0, b=0)
)

# Add the right sunburst with title
fig.add_trace(go.Sunburst(
    labels=labels,
    parents=parents,
    values=counts_FastRefeed,
    marker=dict(colors=colors, colorbar=dict(title='Percent Change')),
    hovertemplate='%{label}<br>Count: %{value}<br>Percent Change: %{customdata:.2f}%',
    customdata=percent_change,
    domain=dict(column=1),
))

fig.update_layout(
    annotations=[
        go.layout.Annotation(
            text='FastRefeed',
            x=0.5,
            y=1.12,
            showarrow=False,
            font=dict(size=16),
            xref='paper',
            yref='paper'
        )
    ],
    grid=dict(columns=2, rows=1),
    margin=dict(t=0, l=0, r=0, b=0)
)

fig.show()

# %%
import json
import plotly.graph_objects as go
import pandas as pd

# Load the JSON file
with open('structures.json', 'r') as f:
    data = json.load(f)

# Read the CSV files
df_Fed = pd.read_csv('Fed.csv')
df_FastRefeed = pd.read_csv('FastRefeed.csv')

# Prepare data for the tree
labels = [item['acronym'] for item in data]
parents = ['' if len(item['structure_id_path']) == 1 else next((i['acronym'] for i in data if i['id'] == item['structure_id_path'][-2])) for item in data]

# Match acronyms with count values from the CSVs
counts_Fed = [df_Fed.loc[df_Fed['acronym'] == acronym, 'density (cells/mm^3)'].iloc[0] if acronym in df_Fed['acronym'].values else None for acronym in labels]
counts_FastRefeed = [df_FastRefeed.loc[df_FastRefeed['acronym'] == acronym, 'density (cells/mm^3)'].iloc[0] if acronym in df_FastRefeed['acronym'].values else None for acronym in labels]

# Calculate percent change in density of cells
percent_change = [(count_fast - count_fed) / count_fed * 100 if count_fed is not None else None for count_fed, count_fast in zip(counts_Fed, counts_FastRefeed)]

# Create a DataFrame with the data
df_data = pd.DataFrame({'labels': labels, 'parents': parents, 'counts_Fed': counts_Fed, 'counts_FastRefeed': counts_FastRefeed, 'percent_change': percent_change})

# Sort the DataFrame by percent_change in descending order
df_sorted = df_data.sort_values('percent_change', ascending=False)

# Update the labels and parents based on the sorted DataFrame
sorted_labels = df_sorted['labels'].tolist()
sorted_parents = df_sorted['parents'].tolist()

# Define the color scale for percent change
color_scale_fed = 'RdBu'
color_scale_fastrefeed = 'RdBu_r'  # Reverse the color scale for FastRefeed sunburst

# Create the figure with subplots
fig = go.Figure()

# Add the left sunburst with title
fig.add_trace(go.Sunburst(
    labels=sorted_labels,
    parents=sorted_parents,
    values=df_sorted['counts_Fed'],  # Assign count values to the sunburst
    marker=dict(colorscale=color_scale_fed, colorbar=dict(title='Percent Change (Fed)')),
    hovertemplate='%{label}<br>Count: %{value}<br>Percent Change: %{marker.color:.2%}',
    domain=dict(column=0),
    insidetextorientation='tangential'
))

fig.update_layout(
    annotations=[
        go.layout.Annotation(
            text='Fed',
            x=0.5,
            y=1.12,
            showarrow=False,
            font=dict(size=16),
            xref='paper',
            yref='paper'
        )
    ],
    grid=dict(columns=2, rows=1),
    margin=dict(t=0, l=0, r=0, b=0)
)

# Add the right sunburst with title
fig.add_trace(go.Sunburst(
    labels=sorted_labels,
    parents=sorted_parents,
    values=df_sorted['counts_FastRefeed'],  # Assign count values to the sunburst
    marker=dict(colorscale=color_scale_fastrefeed, colorbar=dict(title='Percent Change (FastRefeed)')),
    hovertemplate='%{label}<br>Count: %{value}<br>Percent Change: %{marker.color:.2%}',
    domain=dict(column=1),
    insidetextorientation='tangential'
))

fig.update_layout(
    annotations=[
        go.layout.Annotation(
            text='FastRefeed',
            x=0.5,
            y=1.12,
            showarrow=False,
            font=dict(size=16),
            xref='paper',
            yref='paper'
        )
    ],
    grid=dict(columns=2, rows=1),
    margin=dict(t=0, l=0, r=0, b=0)
)

fig.show()

# %%
import json
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# Load the JSON file
with open('structures.json', 'r') as f:
    data = json.load(f)

# Read the CSV files
df_Fed = pd.read_csv('Fed.csv')
df_FastRefeed = pd.read_csv('FastRefeed.csv')

# Prepare data for the tree
labels = [item['acronym'] for item in data]
parents = ['' if len(item['structure_id_path']) == 1 else next((i['acronym'] for i in data if i['id'] == item['structure_id_path'][-2])) for item in data]

# Match acronyms with count values from the CSVs
counts_Fed = [df_Fed.loc[df_Fed['acronym'] == acronym, 'density (cells/mm^3)'].iloc[0] if acronym in df_Fed['acronym'].values else None for acronym in labels]
counts_FastRefeed = [df_FastRefeed.loc[df_FastRefeed['acronym'] == acronym, 'density (cells/mm^3)'].iloc[0] if acronym in df_FastRefeed['acronym'].values else None for acronym in labels]

# Calculate percent change in density of cells
percent_change = [(count_fast - count_fed) / count_fed * 100 if count_fed is not None else None for count_fed, count_fast in zip(counts_Fed, counts_FastRefeed)]

# Define the color scale for percent change
color_scale = [[-100, 'blue'], [0, 'white'], [1000, 'red']]

# Map percent change to color values
colors = [np.interp(pc, [-100, 1000], [0, 1]) if pc is not None else None for pc in percent_change]

# Create the figure with subplots
fig = go.Figure()

# Add the left sunburst with title
fig.add_trace(go.Sunburst(
    labels=labels,
    parents=parents,
    values=counts_Fed,
    marker=dict(colors=colors, colorbar=dict(title='Percent Change', len=0.4)),
    hovertemplate='%{label}<br>Count: %{value}<br>Percent Change: %{customdata:.2f}%',
    customdata=percent_change,
    domain=dict(column=0),
    insidetextorientation='tangential'
))

fig.update_layout(
    annotations=[
        go.layout.Annotation(
            text='Fed',
            x=0.5,
            y=1.12,
            showarrow=False,
            font=dict(size=16),
            xref='paper',
            yref='paper'
        )
    ],
    grid=dict(columns=2, rows=1),
    margin=dict(t=0, l=0, r=0, b=0),
    plot_bgcolor='black'
)

# Add the right sunburst with title
fig.add_trace(go.Sunburst(
    labels=labels,
    parents=parents,
    values=counts_FastRefeed,
    marker=dict(colors=colors, colorbar=dict(title='Percent Change', len=0.4)),
    hovertemplate='%{label}<br>Count: %{value}<br>Percent Change: %{customdata:.2f}%',
    customdata=percent_change,
    domain=dict(column=1),
))

fig.update_layout(
    annotations=[
        go.layout.Annotation(
            text='FastRefeed',
            x=0.5,
            y=1.12,
            showarrow=False,
            font=dict(size=16),
            xref='paper',
            yref='paper'
        )
    ],
    grid=dict(columns=2, rows=1),
    margin=dict(t=0, l=0, r=0, b=0),
    plot_bgcolor='black'
)

fig.show()

# %%
import json
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# Load the JSON file
with open('structures.json', 'r') as f:
    data = json.load(f)

# Read the CSV files
df_Fed = pd.read_csv('Fed.csv')
df_FastRefeed = pd.read_csv('FastRefeed.csv')

# Prepare data for the tree
labels = [item['acronym'] for item in data]
parents = ['' if len(item['structure_id_path']) == 1 else next((i['acronym'] for i in data if i['id'] == item['structure_id_path'][-2])) for item in data]

# Match acronyms with count values from the CSVs
counts_Fed = [df_Fed.loc[df_Fed['acronym'] == acronym, 'density (cells/mm^3)'].iloc[0] if acronym in df_Fed['acronym'].values else None for acronym in labels]
counts_FastRefeed = [df_FastRefeed.loc[df_FastRefeed['acronym'] == acronym, 'density (cells/mm^3)'].iloc[0] if acronym in df_FastRefeed['acronym'].values else None for acronym in labels]

# Calculate percent change in density of cells
percent_change = [(count_fast - count_fed) / count_fed * 100 if count_fed is not None else None for count_fed, count_fast in zip(counts_Fed, counts_FastRefeed)]

# Define the color scale for percent change
color_scale = [[-100, 'blue'], [0, 'white'], [1000, 'red']]

# Map percent change to color values
colors = [np.interp(pc, [0, 300], [0, 1]) if pc is not None else None for pc in percent_change]

# Create the figure with subplots
fig = go.Figure()

# Add the left sunburst with title
fig.add_trace(go.Sunburst(
    labels=labels,
    parents=parents,
    values=counts_Fed,
    marker=dict(colors=colors, colorbar=dict(title='Percent Change')),
    hovertemplate='%{label}<br>Count: %{value}<br>Percent Change: %{customdata:.2f}%',
    customdata=percent_change,
    domain=dict(column=0),
    insidetextorientation='tangential'
))

fig.update_layout(
    annotations=[
        go.layout.Annotation(
            text='Fed',
            x=0.5,
            y=1.12,
            showarrow=False,
            font=dict(size=16),
            xref='paper',
            yref='paper'
        )
    ],
    grid=dict(columns=2, rows=1),
    margin=dict(t=0, l=0, r=0, b=0)
)

# Add the right sunburst with title
fig.add_trace(go.Sunburst(
    labels=labels,
    parents=parents,
    values=counts_FastRefeed,
    marker=dict(colors=colors, colorbar=dict(title='Percent Change')),
    hovertemplate='%{label}<br>Count: %{value}<br>Percent Change: %{customdata:.2f}%',
    customdata=percent_change,
    domain=dict(column=1),
))

fig.update_layout(
    annotations=[
        go.layout.Annotation(
            text='FastRefeed',
            x=0.5,
            y=1.12,
            showarrow=False,
            font=dict(size=16),
            xref='paper',
            yref='paper'
        )
    ],
    grid=dict(columns=2, rows=1),
    margin=dict(t=0, l=0, r=0, b=0)
)

# Print the percent change DataFrame
percent_change_df = pd.DataFrame({'Label': labels, 'Percent Change': percent_change})
print(percent_change_df)

fig.show()
# Out:
# Label  Percent Change
# 0       root      102.328671
# 1       grey       99.894702
# 2         CH      101.749670
# 3        CTX       94.843476
# 4      CTXpl       94.511870
# ...      ...             ...
# 1322     ipf             NaN
# 1323     pms             NaN
# 1324     pfs             NaN
# 1325     IPF             NaN
# 1326  retina             NaN
#
# [1327 rows x 2 columns]

# %%
percent_change_df.to_csv('percent_change.csv', index=False)

# %%
import pandas as pd
df = pd.read_csv('percent_change.csv')

# %%
# Sort the percent change DataFrame by 'Percent Change' column in descending order
percent_change_df = df.sort_values(by='Percent Change', ascending=False)

# Apply color styling based on 'Percent Change' values
percent_change_df_styled = percent_change_df.style.background_gradient(
    cmap='RdBu',
    subset=['Percent Change'],
    vmin=-100, vmax=100  # Set the range for color mapping
)

# Display the styled DataFrame
percent_change_df_styled
# Out:
# <style type="text/css">
# ...

# %%
# !pip install Jinja2
# Out:
# ...
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# ...

# %%
# !pip install dash

# %%
import dash

# %%
import json
import plotly.graph_objects as go
import pandas as pd
import numpy as np

# Load the JSON file
with open('structures.json', 'r') as f:
    data = json.load(f)

# Read the CSV file
df = pd.read_csv('percent_change.csv')

# Prepare data for the tree
labels = [item['acronym'] for item in data]
parents = ['' if len(item['structure_id_path']) == 1 else next((i['acronym'] for i in data if i['id'] == item['structure_id_path'][-2])) for item in data]

# Match acronyms with count values from the CSV
changes = [df.loc[df['acronym'] == acronym, 'change'].iloc[0] if acronym in df['acronym'].values else np.nan for acronym in labels]

# Replace NaN values with a default value
default_value = 0.0
changes = [default_value if pd.isnull(change) else change for change in changes]

colors = ['rgb{}'.format(tuple(item['rgb_triplet'])) for item in data]

# Create a Plotly figure
fig = go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    values=changes,
    marker=dict(colors=colors),
    hovertemplate='<b>%{label}</b><br>Percent Change: %{value}<extra></extra>',  # Customize hover text
))

fig.update_layout(margin=dict(t=0, l=0, r=0, b=0))

fig.show()

# %%
import numpy as np
from scipy.cluster.hierarchy import linkage
import plotly.figure_factory as ff

# Generate some random data
X = np.random.rand(10, 2)

# Generate a linkage matrix
Z = linkage(X, 'ward')

# Create a dendrogram
dendro = ff.create_dendrogram(Z, orientation='right')

# Display the dendrogram
dendro.show()

# %%
print(len(labels))
# Out:
# 1327

# %%
print(labels)
# Out:
# tral part of the lateral geniculate complex, medial zone', 'Subgeniculate nucleus', 'Epithalamus', 'Medial habenula', 'Lateral habenula', 'Pineal body', 'Hypothalamus', 'Periventricular zone', 'Supraoptic nucleus', 'Accessory supraoptic group', 'Nucleus circularis', 'Paraventricular hypothalamic nucleus', 'Paraventricular hypothalamic nucleus, magnocellular division', 'Paraventricular hypothalamic nucleus, magnocellular division, anterior magnocellular part', 'Paraventricular hypothalamic nucleus, magnocellular division, medial magnocellular part', 'Paraventricular hypothalamic nucleus, magnocellular division, posterior magnocellular part', 'Paraventricular hypothalamic nucleus, magnocellular division, posterior magnocellular part, lateral zone', 'Paraventricular hypothalamic nucleus, magnocellular division, posterior magnocellular part, medial zone', 'Paraventricular hypothalamic nucleus, parvicellular division', 'Paraventricular hypothalamic nucleus, parvicellular division, anterio
# ...

# %%
import plotly.express as px
import json

# Load the JSON file
with open('structures.json', 'r') as f:
    data = json.load(f)

# Create lists to store the data
labels = [item['name'] for item in data]
parents = ['' if len(item['structure_id_path']) == 1 else next((i['name'] for i in data if i['id'] == item['structure_id_path'][-2])) for item in data]
values = [item['graph_order'] for item in data]

colors = ['rgb{}'.format(tuple(item['rgb_triplet'])) for item in data]

fig = px.treemap(
    names=labels,
    parents=parents,
    values=values, 
    color=colors,
    color_discrete_sequence=colors,  # this will set the color sequence
    title="Structures Treemap"
)

fig.show()

# %%
# !pip install pandas
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 757.5 kB/s eta 0:00:00
# ...

# %%
import plotly.graph_objects as go

fig = go.Figure(go.Treemap(
    labels=labels,
    parents=parents,
    values=values,
    marker=dict(colors=colors)
))

fig.show()

# %%
import plotly.graph_objects as go
import networkx

edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

node_x = []
node_y = []
for node in pos:
    x, y = pos[node]
    node_x.append(x)
    node_y.append(y)

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        showscale=True,
        colorscale='YlGnBu',
        reversescale=True,
        color=[],
        size=10,
        colorbar=dict(
            thickness=15,
            title='Node Connections',
            xanchor='left',
            titleside='right'
        ),
        line_width=2))

node_adjacencies = []
node_text = []
for node, adjacencies in enumerate(G.adjacency()):
    node_adjacencies.append(len(adjacencies[1]))
    node_text.append(f'Node {node} has {len(adjacencies[1])} connections')

node_trace.marker.color = node_adjacencies
node_trace.text = node_text

fig = go.Figure(data=[edge_trace, node_trace],
             layout=go.Layout(
                title='<br>Network graph',
                titlefont_size=16,
                showlegend=False,
                hovermode='closest',
                margin=dict(b=20,l=5,r=5,t=40),
                annotations=[ dict(
                    text="Graph data",
                    showarrow=False,
                    xref="paper", yref="paper",
                    x=0.005, y=-0.002 ) ],
                xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
                yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
                )
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 edge_x = []
#       5 edge_y = []
# ----> 6 for edge in G.edges():
#       7     x0, y0 = pos[edge[0]]
#       8     x1, y1 = pos[edge[1]]
#
# NameError: name 'G' is not defined

# %%
import pandas as pd
from io import StringIO



df = pd.read_csv('Female1_Restraint_Fos_output.csv')

def generate_hierarchy(df, parent_id, parent_path):
    children = df[df['parent_structure_id'] == parent_id]
    if children.empty:
        return None
    else:
        hierarchy = []
        for idx, row in children.iterrows():
            path = parent_path + "/" + row['name']
            node = {
                "name": row['name'],
                "path": path,
                "value": row['count'],
                "children": generate_hierarchy(df, row['id'], path)
            }
            hierarchy.append(node)
        return hierarchy

hierarchy = generate_hierarchy(df, -1, "")

import plotly.express as px

fig = px.sunburst(
    hierarchy,
    path=['path'],
    values='value'
)
fig.show()

# %%
import json
print(json.dumps(hierarchy, indent=2))
# Out:
# forceps/right external capsule",
#                         "value": 3908.0,
#                         "children": null
#                       }
#                     ]
#                   },
#                   {
#                     "name": "right corpus callosum, extreme capsule",
#                     "path": "/right root/right fiber tracts/right lateral forebrain bundle system/right corpus callosum/right corpus callosum, extreme capsule",
#                     "value": 911.0,
#                     "children": null
#                   },
#                   {
#                     "name": "right genu of corpus callosum",
#                     "path": "/right root/right fiber tracts/right lateral forebrain bundle system/right corpus callosum/right genu of corpus callosum",
#                     "value": 1473.0,
#                     "children": null
#                   },
#                   {
#                     "name": "right corpus callosum, posterior forceps",
# ...

# %%
# !ipywidgets
# Out:
# /bin/bash: ipywidgets: command not found

# %%
import pandas as pd
import plotly.graph_objects as go

df = pd.read_csv('Female1_Restraint_Fos_output.csv')

def generate_hierarchy(df, parent_id, parent_path):
    children = df[df['parent_structure_id'] == parent_id]
    if children.empty:
        return None
    else:
        hierarchy = []
        for idx, row in children.iterrows():
            if row['depth'] == 1:  # Ignore levels -1 and -2
                continue
            path = parent_path + "/" + row['name']
            node = {
                "name": row['name'],
                "path": path,
                "valueidw['count'],
                "children": generate_hierarchy(df, row['id'], path)
            }
            hierarchy.append(node)
        return hierarchy

hierarchy = generate_hierarchy(df, 1, "")  # Start hierarchy from parent_structure_id = 0

def add_trace(node):
    if node['children'] is not None:
        for child in node['children']:
            add_trace(child)
    return go.Sunburst(
        labels=[node['name']],
        parents=[""],
        values=[node['id']],
        branchvalues='total',
    )

if hierarchy:  # Check if hierarchy is not empty
    fig = go.Figure(add_trace(hierarchy[0]))

    fig.update_layout(margin=dict(t=0, l=0, r=0, b=0))

    fig.show()
else:
    print("No data found for the specified parent_structure_id.")
# Out:
#   Cell In[15], line 19
#     "valueidw['count'],
#                        ^
# SyntaxError: EOL while scanning string literal

# %%
print(hierarchy)
# Out:
# ght cranial nerves/right oculomotor nerve/right posterior commissure', 'value': 11121, 'children': None}]}, {'name': 'right trochlear nerve', 'path': '/right root/right fiber tracts/right cranial nerves/right trochlear nerve', 'value': 11122, 'children': None}, {'name': 'right trigeminal nerve', 'path': '/right root/right fiber tracts/right cranial nerves/right trigeminal nerve', 'value': 11125, 'children': [{'name': 'right motor root of the trigeminal nerve', 'path': '/right root/right fiber tracts/right cranial nerves/right trigeminal nerve/right motor root of the trigeminal nerve', 'value': 11126, 'children': None}, {'name': 'right sensory root of the trigeminal nerve', 'path': '/right root/right fiber tracts/right cranial nerves/right trigeminal nerve/right sensory root of the trigeminal nerve', 'value': 11127, 'children': [{'name': 'right spinal tract of the trigeminal nerve', 'path': '/right root/right fiber tracts/right cranial nerves/right trigeminal nerve/right sensory root 
# ...
